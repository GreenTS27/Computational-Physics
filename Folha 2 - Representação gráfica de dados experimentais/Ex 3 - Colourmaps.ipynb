# %%
from numpy import loadtxt
from pylab import show,imshow,gray,jet,hot,bone,hsv,nipy_spectral,spring,autumn,cool,copper,flag,inferno,magma,pink,plasma,prism,summer,viridis,winter
# há mais cores em matplotlib.pyplot

data = loadtxt("stm.txt")
imshow(data, origin="lower")
gray() #este é um dos melhores para perceber os dados
#bone()
show()

# ró = m/V --> maior altura = maior Volume = menor ró/densidade

# %%
imshow(data, origin="lower", extent=[0,100,0,75])
gray()
show()

# %%
imshow(data, origin="lower")
jet()
show()

# %%
imshow(data, origin="lower")
hot()
show()

# %%
imshow(data, origin="lower")
bone()
show()

# %%
imshow(data, origin="lower")
hsv()
show()

# %%
imshow(data, origin="lower")
nipy_spectral()
show()

# %%
imshow(data, origin="lower")
spring()
show()

# %%
imshow(data, origin="lower")
autumn()
show()

# %%
imshow(data, origin="lower")
cool()
show()

# %%
imshow(data, origin="lower")
copper()
show()

# %%
imshow(data, origin="lower")
flag()
show()

# %%
imshow(data, origin="lower")
inferno()
show()

# %%
imshow(data, origin="lower")
magma()
show()

# %%
imshow(data, origin="lower")
pink()
show()

# %%
imshow(data, origin="lower")
plasma()
show()

# %%
imshow(data, origin="lower")
prism()
show()

# %%
imshow(data, origin="lower")
summer()
show()

# %%
imshow(data, origin="lower")
viridis()
show()

# %%
imshow(data, origin="lower")
winter()
show()
